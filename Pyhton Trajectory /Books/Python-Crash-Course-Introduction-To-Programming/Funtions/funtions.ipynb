# %% [markdown]
# # 📁 Functions

# %% [markdown]
# ### Functions in Python are used to organize reusable blocks of code.
# A function is a named sequence of statements that perform a specific task. Functions help break programs into smaller, modular pieces, making code easier to read, maintain, and reuse.
#
# Functions can take input (parameters), perform operations, and return output (values). They are one of the most important building blocks in Python programming.
#
# ---
#
# **Key features of functions:**
# - Defined using the `def` keyword followed by the function name and parentheses.
# - Can take zero or more parameters (inputs).
# - Can return a value using the `return` statement.
# - Improve code reusability and readability.
# - Support default parameters, keyword arguments, and variable-length arguments (`*args`, `**kwargs`).
# - Python also supports anonymous functions using the `lambda` keyword.
#
# ---
#
# **Parts of a function:**
# - **Function name**: A unique identifier that describes what the function does. Used to call (invoke) the function later.
# - **Parameters**: Variables listed inside parentheses after the function name. They act as placeholders for values (arguments) passed into the function.
# - **Body**: The indented block of code inside the function. This is where the logic or task of the function is written.
# - **Return value**: The output of the function, specified with the `return` keyword. If no return is provided, the function returns `None`.
#
# ---
#
# **Common operations:**
# - Defining a function with `def`.
# - Calling a function by its name followed by parentheses.
# - Passing arguments to customize behavior.
# - Returning values for later use.
# - Using `*args` for arbitrary positional arguments.
# - Using `**kwargs` for arbitrary keyword arguments.
#
# ---
#
# **Use cases of functions:**
# - Encapsulating repetitive tasks into reusable code.
# - Organizing large programs into smaller, logical sections.
# - Reducing redundancy and improving maintainability.
# - Implementing modular design and separation of concerns.
# - Supporting functional programming with higher-order functions.
#
# ---
#
# 👉 Functions are essential for structuring Python programs, allowing you to write cleaner, more efficient, and more maintainable code.

# %% [markdown]
# # 📁 Defining a function

# %% [markdown]
# ### Simple Function

# %%
def greet_user():
    """
    This function greets the user.
    """
    print("Hello, world!")

greet_user()

# %% [markdown]
# ### Passing information to a function

# %%
def greet_user(username):
    """Display a simple greeting."""
    print(f"Hello, {username.title()}!")

greet_user('jesse')

# %% [markdown]
# # 📁 Positional Argument

# %% [markdown]
# ### Posional arguments

# %%
def describe_pet(animal_type, pet_name):
    """Display information about a pet."""
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet('hamster', 'harry')

# %% [markdown]
# ### Multiple functions calls

# %%
def describe_pet(animal_type, pet_name):
    """Display information about a pet."""
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet('hamster', 'harry')
describe_pet('dog', 'willie')

# %% [markdown]
# ### Order matter in positional arguments

# %%
def describe_pet(animal_type, pet_name):
    """Display information about a pet."""
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet("harry",'hamster')

# %% [markdown]
# ### Keyword arguments

# %%
def describe_pet(animal_type, pet_name):
    """Display information about a pet."""
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet(pet_name='harry', animal_type='hamster')
describe_pet(animal_type='hamster',pet_name='harry')

# %% [markdown]
# ### Default values

# %%
def deescribe_pet(pet_name,animal_type='dog'):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

deescribe_pet('willie')
deescribe_pet('harry', 'hamster')

# %% [markdown]
# ### Avoiding argument Errors

# %%
def describe_pet(pet_name, animal_type):
    """Display information about a pet."""
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet('harry', 'hamster')

# %% [markdown]
# # 📁 Return Values

# %% [markdown]
# ### Returning simple values

# %%
def get_formatted_name(first_name, last_name):
    """Return a full name, neatly formatted."""
    full_name = f"{first_name} {last_name}"
    return full_name.title()

musician = get_formatted_name('jimi', 'hendrix')
print(musician)

# %% [markdown]
# ### Making an Argument optional

# %%
def get_formatted_name(first_name,middle_name, last_name):
    """Return a full name, neatly formatted."""
    full_name = f"{first_name} {middle_name} {last_name}"
    return full_name.title()

musician = get_formatted_name('jimi', 'lee', 'hendrix')
musician = get_formatted_name('jimi', 'lee', 'hendrix')
print(musician)

# %%
def get_formatted_name(first_name, last_name, middle_name=''):
    """Return a full name, neatly formatted."""
    if middle_name:
        full_name = f"{first_name} {middle_name} {last_name}"
    else:
        full_name = f"{first_name} {last_name}"
    return full_name.title()

musician = get_formatted_name('jimi', 'lee', 'hendrix')
print(musician)

musician = get_formatted_name('jimi', 'hendrix')
print(musician)
print(musician)

# %% [markdown]
# # 📁 Returning a Dictionary

# %%
def build_person(firts_name, last_name):
    """ Return a dictionary about a person,  """
    person = {'first': firts_name, 'last': last_name}
    return person
musician = build_person('jimi', 'hendrix')
print(musician)

# %%
def build_person(firts_name, last_name, age=None):
    
    person = {'first': firts_name, 'last': last_name}
    if age:
        person['age'] = age
    return person
musician = build_person('jimi', 'hendrix',age=27)
print(musician)

# %% [markdown]
# # 📁 Using funtion with a while loop

# %% [markdown]
# ### infinite loop

# %% [markdown]
# ### Simple structure of  while loop  and  function

# %% [markdown]
# def get_formatted_name(firts_name, last_name):
#     full_name = f"{firts_name}{last_name}"
#     return full_name.title()
# while True:
#     print("\nPlease tell me your name:")
#     print("(enter 'q' at any time to quit )")
#
#     f_name = input("First name : ")
#     if f_name == 'q':
#         break
#
#     l_name = input("Last name:")
#     if l_name == 'q':
#         break
#
#     formatted_name = get_formatted_name(f_name, l_name)
#     print(f"\nHello, {formatted_name}!")

# %% [markdown]
#  def get_formatted_name(firts_name, last_name):
#      full_name = f"{firts_name}  {last_name}"
#      return full_name.title()
#  while True:
#      print("\nPlease tell me your name:")
#      print("(enter 'q' at any time to quit )")
#
#      f_name = input("First name : ")
#      if f_name == 'q':
#          break
#      l_name = input("Last name:")
#      if l_name == 'q':
#          break
#
#      formatted_name = get_formatted_name(f_name, l_name)
#      print(f"\nHello, {formatted_name}!")

# %% [markdown]
# def greet_users(names):
#
#     for name in names:
#         msg = f"Hello, {name.title()} ! "
#         print(msg)
#
# usernames = ['hannna', 'ty','margot']
#
# greet_users(usernames)

# %%
def nvmmr(nvm, make_ready_nvm):

    while make_ready_nvm:
        current_desings = make_ready_nvm.pop()
        print(f"status:{current_desings}")
        nvm.append(current_desings)


def show_full(nvm):
    print("\nThe following status have been printed :")

    for nvms in nvm:
        print(nvms)



make_ready_nvm = ['notice', 'vacant', 'schedule to move in ', 'move in']
nvm = []

nvmmr(nvm, make_ready_nvm)
mr = show_full(nvm)

# %% [markdown]
# # 📁 Passing arbitrary number of arguments

# %%
def make_pizza1(size, *toppings):
    """Print the list of toppings that have been requested."""
    print(f"\n Making a {size} -inch pizza with  the folling toppings")
    for topping in toppings:
        print(f"- {topping}")


make_pizza1(16,'pepperoni')
make_pizza1(24,'pepperoni', 'mushrooms', 'green peppers', 'extra cheese')

# %%
def make_pizza(*toppings):
    """Print the list of toppings that have been requested."""
    print("\nMaking a pizza with  the folling toppings")
    for topping in toppings:
        print(f"- {topping}")


make_pizza('pepperoni')
make_pizza('pepperoni', 'mushrooms', 'green peppers', 'extra cheese')

# %% [markdown]
# # 📁 using albitrary keyword argument

# %%
def build_profile(first, last, **user_info):
    user_info['first_name'] = first
    user_info['last_name'] = last
    return user_info

user = build_profile('albert', 'einstein', location='princeton', field='physics')
print(user)
# Out:
# {'location': 'princeton', 'field': 'physics', 'first_name': 'albert', 'last_name': 'einstein'}
