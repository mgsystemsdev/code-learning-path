# %% [markdown]
# # 📁 Dictonaries

# %% [markdown]
# ## Dictionary in python are used to store key-value pairs. A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
# A dictionary in Python is a built-in data structure that stores data as key-value pairs. Each key in a dictionary is unique, and is used to access its corresponding value. Dictionaries are mutable, meaning you can change, add, or remove key-value pairs after the dictionary is created.
#
# **Key features of dictionaries:**
# - Defined using curly braces `{}` with keys and values separated by colons, e.g. `my_dict = {'key1': 'value1', 'key2': 'value2'}`
# - Keys must be immutable types (like strings, numbers, or tuples)
# - Values can be any type (strings, numbers, lists, other dictionaries, etc.)
# - Dictionaries are unordered (prior to Python 3.7), but from Python 3.7+, they maintain insertion order
#
# **Common operations:**
# - Access a value: `my_dict['key1']`
# - Add or update a key-value pair: `my_dict['key3'] = 'value3'`
# - Remove a key-value pair: `del my_dict['key1']`
# - Get all keys: `my_dict.keys()`
# - Get all values: `my_dict.values()`
# - Get all key-value pairs: `my_dict.items()`
#
# Dictionaries are widely used for fast lookups, configuration storage, and representing structured data.

# %% [markdown]
# #  📁  Handling missing keys

# %% [markdown]
# ## Using get() to access values in a dictionary

# %%
alien_0 = {'color':'green', 'speed':'slow'}

point_value = alien_0.get('points','no points value assigned')
print(point_value)

# %% [markdown]
# # 📁 Working with dictionarys

# %% [markdown]
# ## A simple dictionary

# %%
alien_0 = {'color': 'green', 'points': 5}
alien_x = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 15}

print(alien_0['color'])
print(alien_0['points'])

# %% [markdown]
# ## Working with dictionaries

# %%
alien_0 = {'color': 'green', 'points': 5}

alien_0 = {'color': 'green'}

# %% [markdown]
# ## Accesing  value in a dictionary

# %%
alien_0 = {'color': 'green'}
print(alien_0['color'])

alien_0 = {'color': 'green', 'points': 5}

new_points = alien_0['points']
print(f"you just earn {new_points} points!")

# %% [markdown]
# ## Adding new key-value pairs to a dictionary

# %%
alien_0 = {'color': 'green', 'points': 5}
print(alien_0)



alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)

# %% [markdown]
# ## Starting with an empty dictionary

# %%
alien_0 = {}

alien_0['color'] = 'green'
alien_0['points'] = 5
print(alien_0)

# %% [markdown]
# ## Modifying values in a dictionary

# %%
alien_0 = {'color': 'green'}
print(f"The alien is {alien_0['color']}.")

alien_0['color'] = 'yellow'
print(f"The alien is now {alien_0['color']}.")

# %% [markdown]
# ## Removing key-value pairs

# %%
alien_0 = {'color': 'green', 'points': 5}
print(alien_0)
del alien_0['points']
print(alien_0)

# %% [markdown]
# ## A list of dictionaries

# %%
aliens = [alien_x, alien_1, alien_2]

for alien in aliens:
    print(alien)

# %%
aliens = []

for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

for alien in aliens[:20]:
    print(alien)

print("...")



print(f"Total number of aliens :{len(aliens)}")

# %%
aliens = []

for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

for alien in aliens[:3]:
    if alien['color'] == 'green':
        alien['color'] = 'yellow'
        alien['points'] = 10
        alien['speed'] = 'medium'
    

for alien in aliens[:10]:
    print(alien)
print("...")

# %%
aliens = []

for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

for alien in aliens[:4]:
    if alien['color'] == 'green':
        alien['color'] = 'yellow'
        alien['points'] = 10
        alien['speed'] = 'medium'

for alien in aliens[:4]:
    if alien['color'] == 'yellow':
        alien['color'] = 'red'
        alien['speed'] = 'fast'
        alien['points'] = 15

for alien in aliens[:15]:
    print(alien)
print("...")

# %%
"""
Cell generated by Data Wrangler.
"""
import pandas as pd

def clean_data(alien_0_df):
    return alien_0_df

# Loaded variable 'alien_0' from kernel state
alien_0_df = pd.DataFrame.from_dict(alien_0, orient='index')

alien_0_df_clean = clean_data(alien_0_df.copy())
alien_0_df_clean.head()

# %% [markdown]
# # 📁 Loops and dictionarys

# %% [markdown]
# ## A dictionary of similar objects

# %%
favorites_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
}


language = favorites_languages['sarah'].title()
print(f"Sarah's favorite language is {language}.")

# %% [markdown]
# ## Looping thorught  all keys in dictionary

# %%
for name, language in favorites_languages.items():
    print(f"{name.title()}'s favorite language is {language.title()}.")

for name in favorites_languages.keys():
    print(name.title())



friends = ['phil', 'sarah']
for name in favorites_languages.keys():
    print(f"Hi {name.title()}.")

    if name in friends:
        language = favorites_languages[name].title()
        print(f"\t{name.title()}, I see you love  {language}.")



if 'erin' not in favorites_languages.keys():
    print("Erin, please take our poll!")

# %% [markdown]
# ## Looping through dictionary in particular oder

# %%
for name in sorted(favorites_languages.keys()):
    print(f"{name.title()}, thank you for taking the poll.")

# %% [markdown]
# ## Looping through all values in a dictionary

# %%
favorites_languages = {
    'jen': ['python', 'ruby'],
    'sarah': ['c'],
    'edward': ['ruby', 'go'],
    'phil': ['python', 'haskell'],
}
 

for name,language in favorites_languages.items():
    print(f"\n{name.title()}'s favorite languages are ")
    for language in language:
        print(f"\t{language.title()}")

# %% [markdown]
# ## A dictionary in a dictionary

# %%
users = {
    'aeinstein': {
        'first': 'albert',
        'last': 'einstein',
        'location': 'princeton'
    },

    'mcurie': {
        'first': 'marie',
        'last': 'curie',
        'location': 'paris'
    }
}


for username, user_info  in users.items():
    print(f"\nUsername: {username}")
    full_name = f"{user_info['first']} {user_info['last']}"
    location = user_info['location']
    print(f"\tFull Name: {full_name.title()}")
    print(f"\tLocation: {location.title()}")

# %% [markdown]
# # 📁 List and dictionary

# %% [markdown]
# ## A list in a dictionary

# %%
pizza = {
    'crust': 'thick',
    'toppings': ['mushrooms', 'extra cheese']
}


#sumarized your order


print(f"You ordered a {pizza['crust']}-crust pizza with the following toppings:")

for topping in pizza['toppings']:
    print(f"\t{topping}")

# %% [markdown]
# #  📁 Looping through the dictionary

# %% [markdown]
# ## Looping through the dictionary

# %%
user_0 ={
    'username': 'efermi',
    'first': 'enrico',
    'last' : 'fermi'
}



for k, v in user_0.items():
    print(f"\nkey:{k}")
    print(f"value:{v}")
